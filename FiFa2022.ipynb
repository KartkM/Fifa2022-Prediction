# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv("C:\\Users\\Public\\Skill\\Simplilearn\\Data Analyst\\Programming Basics and Data Analytics with Python\\Project\\Fifa 2022\\FIFA22_official_data.csv")

# %%
fifa.head()
# Out:
#        ID             Name  Age  \
# 0  212198  Bruno Fernandes   26
# 1  209658      L. Goretzka   26
# 2  176580        L. Suárez   34
# 3  192985     K. De Bruyne   30
# 4  224334         M. Acuña   29
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1  https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2  https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/pt.png       88         89
# 1  https://cdn.sofifa.com/flags/de.png       87         88
# 2  https://cdn.sofifa.com/flags/uy.png       88         88
# 3  https://cdn.sofifa.com/flags/be.png       91         91
# 4  https://cdn.sofifa.com/flags/ar.png       84         84
#
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Best Position
# Best Overall Rating
# Release Clause
# DefensiveAwareness

# %%
fifa.shape
# Out:
# (16710, 65)

# %%
16710*104
# Out:
# 1737840

# %%
fifa['Nationality'].value_counts()
# Out:
# England                1845
# Spain                  1151
# Germany                1120
# France                  987
# Argentina               846
#                        ...
# Belize                    1
# São Tomé e Príncipe       1
# Rwanda                    1
# Tanzania                  1
# Oman                      1
# Name: Nationality, Length: 168, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:10]
# Out:
# England          1845
# Spain            1151
# Germany          1120
# France            987
# Argentina         846
# Brazil            819
# Italy             514
# Netherlands       443
# Portugal          354
# United States     341
# Name: Nationality, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:5]
# Out:
# England      1845
# Spain        1151
# Germany      1120
# France        987
# Argentina     846
# Name: Nationality, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Spain', 'Germany', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['Nationality'].value_counts()[0:5].keys()), list(fifa['Nationality'].value_counts()[0:5]),color="g")
plt.show()

# %%
player_salary = fifa[['Name','Wage']]

# %%
player_salary.head()
# Out:
#               Name   Wage
# 0  Bruno Fernandes  €250K
# 1      L. Goretzka  €140K
# 2        L. Suárez  €135K
# 3     K. De Bruyne  €350K
# 4         M. Acuña   €45K

# %%
player_salary=player_salary.sort_values(by=['Wage'],ascending=False)

# %%
player_salary.head()
# Out:
#                Name Wage
# 8771          Rober  €9K
# 3132     Igor Silva  €9K
# 10418  F. Bonazzoli  €9K
# 14160     J. Chabot  €9K
# 5126        A. Long  €9K

# %%
plt.figure(figsize=(5,5))
plt.bar(list(player_salary['Name'])[0:5],list(player_salary['Wage'])[0:5],color=["blue","green","orange"])
plt.show()

# %%
fifa['Nationality']=='Germany'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 16705    False
# 16706    False
# 16707    False
# 16708    False
# 16709    False
# Name: Nationality, Length: 16710, dtype: bool

# %%
Germany=fifa[fifa['Nationality']=='Germany']
Germany.head(10)
# Out:
#          ID           Name  Age  \
# 1    209658    L. Goretzka   26
# 5    212622     J. Kimmich   26
# 8    208333         E. Can   27
# 47   186942    I. Gündoğan   30
# 54   223697      R. Gosens   26
# 67     3647  12 M. Ballack   34
# 102  206511      M. Arnold   27
# 116  182521       T. Kroos   31
# 120  187072      L. Stindl   32
# 125  121939     17 P. Lahm   32
#
#                                                 Photo Nationality  \
# 1    https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 5    https://cdn.sofifa.com/players/212/622/22_60.png     Germany
# 8    https://cdn.sofifa.com/players/208/333/22_60.png     Germany
# 47   https://cdn.sofifa.com/players/186/942/22_60.png     Germany
# 54   https://cdn.sofifa.com/players/223/697/22_60.png     Germany
# 67   https://cdn.sofifa.com/players/003/647/12_60.png     Germany
# 102  https://cdn.sofifa.com/players/206/511/22_60.png     Germany
# 116  https://cdn.sofifa.com/players/182/521/22_60.png     Germany
# ...

# %%
Germany.sort_values(by=['Height'],ascending=False).head()
# Out:
#            ID            Name  Age  \
# 15204  262899      C. Ezekwem   22
# 14817  259082  21 J. Lawrence   17
# 16584  253410         J. Hupe   21
# 12817  236831       A. Seydel   25
# 15460  200212        M. Esser   33
#
#                                                   Photo Nationality  \
# 15204  https://cdn.sofifa.com/players/262/899/22_60.png     Germany
# 14817  https://cdn.sofifa.com/players/259/082/21_60.png     Germany
# 16584  https://cdn.sofifa.com/players/253/410/22_60.png     Germany
# 12817  https://cdn.sofifa.com/players/236/831/22_60.png     Germany
# 15460  https://cdn.sofifa.com/players/200/212/22_60.png     Germany
#
#                                       Flag  Overall  Potential  \
# 15204  https://cdn.sofifa.com/flags/de.png       61         67
# 14817  https://cdn.sofifa.com/flags/de.png       61         78
# 16584  https://cdn.sofifa.com/flags/de.png       58         70
# 12817  https://cdn.sofifa.com/flags/de.png       65         68
# ...

# %%
Germany.sort_values(by=['Weight'],ascending=False).head()
# Out:
#            ID         Name  Age  \
# 8698   212190      N. Süle   25
# 10398  213331       J. Tah   25
# 15969  210022    P. Sprint   28
# 15820  179783  R. Fährmann   32
# 16488  241388   D. Smarsch   22
#
#                                                   Photo Nationality  \
# 8698   https://cdn.sofifa.com/players/212/190/22_60.png     Germany
# 10398  https://cdn.sofifa.com/players/213/331/22_60.png     Germany
# 15969  https://cdn.sofifa.com/players/210/022/22_60.png     Germany
# 15820  https://cdn.sofifa.com/players/179/783/22_60.png     Germany
# 16488  https://cdn.sofifa.com/players/241/388/22_60.png     Germany
#
#                                       Flag  Overall  Potential  \
# 8698   https://cdn.sofifa.com/flags/de.png       82         87
# 10398  https://cdn.sofifa.com/flags/de.png       78         82
# 15969  https://cdn.sofifa.com/flags/de.png       62         64
# 15820  https://cdn.sofifa.com/flags/de.png       74         74
# ...

# %%
Germany[['Name','Height']].sort_values(by=['Height'],ascending=False).head()
# Out:
#                  Name Height
# 15204      C. Ezekwem  202cm
# 14817  21 J. Lawrence  200cm
# 16584         J. Hupe  200cm
# 12817       A. Seydel  199cm
# 15460        M. Esser  198cm

# %%
Germany[['Name','Weight']].sort_values(by=['Weight'],ascending=False).head()
# Out:
#               Name Weight
# 8698       N. Süle   99kg
# 10398       J. Tah   98kg
# 15969    P. Sprint   98kg
# 15820  R. Fährmann   98kg
# 16488   D. Smarsch   97kg

# %%
Germany[['Name','Wage']].sort_values(by=['Wage'],ascending=False).head()
# Out:
#                Name Wage
# 4466      M. Thiede  €9K
# 2686    M. Stendera  €9K
# 16120   L. Zingerle  €9K
# 10569   T. Leistner  €9K
# 6398   J. Schöppner  €9K

# %%
player_shooting = fifa[['Name','ShortPassing']]

# %%
player_shooting.sort_values(by=['ShortPassing'],ascending=False).head()
# Out:
#              Name  ShortPassing
# 3    K. De Bruyne          94.0
# 244       15 Xavi          93.0
# 116      T. Kroos          93.0
# 92         Parejo          92.0
# 830  Luis Alberto          92.0

# %%
player_strength=fifa[['Name','Strength','Nationality','Club']]

# %%
player_strength.sort_values(by=['Strength'],ascending=False).head()
# Out:
#                Name  Strength     Nationality                       Club
# 11849  A. Akinfenwa      97.0         England          Wycombe Wanderers
# 12612       D. Dike      96.0   United States   Orlando City Soccer Club
# 13220   T. Petrášek      96.0  Czech Republic          Raków Częstochowa
# 8807      A. Méndez      95.0         Uruguay  Club Nacional de Football
# 425       R. Lukaku      95.0         Belgium                    Chelsea

# %%
club = fifa['Club'].tolist()

# %%
print('Club:',club)
# Out:
# Club: ['Manchester United', 'FC Bayern München', 'Atlético de Madrid', 'Manchester City', 'Sevilla FC', 'FC Bayern München', 'Al Ahli', 'Paris Saint-Germain', 'Borussia Dortmund', 'Atlético de Madrid', 'Real Madrid CF', 'Atlético de Madrid', 'Paris Saint-Germain', 'Real Madrid CF', 'Real Sociedad', 'Inter', 'Manchester United', 'FC Barcelona', 'FC Bayern München', 'Juventus', 'Atlético de Madrid', 'Manchester City', 'Everton', 'Eintracht Frankfurt', 'Liverpool', 'Lazio', 'Inter', 'Manchester United', 'Real Madrid CF', 'Paris Saint-Germain', 'LOSC Lille', 'Sevilla FC', 'FC Barcelona', 'FC Bayern München', 'Liverpool', 'RB Leipzig', 'Manchester United', 'FC Anzhi Makhachkala', 'Real Betis Balompié', 'Tottenham Hotspur', 'Paris Saint-Germain', 'Inter', 'Paris Saint-Germain', 'Chelsea', 'Liverpool', 'Roma', 'Liverpool', 'Manchester City', 'Royal Antwerp FC', 'Sevilla FC', 'Olympique Lyonnais', 'AC Milan', 'Atalanta', 'Manchester City', 'Atalanta', 'Liverpool', 'Roma', 'Valencia CF', 'Par
# ...

# %%
fc=fifa[fifa['Club']=='FC Bayern München']

# %%
fc.sort_values(by=['Wage'],ascending=False).head()
# Out:
#            ID          Name  Age  \
# 13330  250955   J. Stanišić   21
# 16458  235266    C. Früchtl   21
# 9135   256887      T. Booth   20
# 12350  167495      M. Neuer   35
# 852    220814  L. Hernández   25
#
#                                                   Photo    Nationality  \
# 13330  https://cdn.sofifa.com/players/250/955/22_60.png        Croatia
# 16458  https://cdn.sofifa.com/players/235/266/22_60.png        Germany
# 9135   https://cdn.sofifa.com/players/256/887/22_60.png  United States
# 12350  https://cdn.sofifa.com/players/167/495/22_60.png        Germany
# 852    https://cdn.sofifa.com/players/220/814/22_60.png         France
#
#                                       Flag  Overall  Potential  \
# 13330  https://cdn.sofifa.com/flags/hr.png       64         75
# 16458  https://cdn.sofifa.com/flags/de.png       66         76
# 9135   https://cdn.sofifa.com/flags/us.png       62         75
# 12350  https://cdn.sofifa.com/flags/de.png       90         90
# ...

# %%
fc.sort_values(by=['ShortPassing'],ascending=False).head()
# Out:
#          ID            Name  Age  \
# 522   45197  17 Xabi Alonso   34
# 5    212622      J. Kimmich   26
# 1    209658     L. Goretzka   26
# 125  121939      17 P. Lahm   32
# 33   188545  R. Lewandowski   32
#
#                                                 Photo Nationality  \
# 522  https://cdn.sofifa.com/players/045/197/17_60.png       Spain
# 5    https://cdn.sofifa.com/players/212/622/22_60.png     Germany
# 1    https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 125  https://cdn.sofifa.com/players/121/939/17_60.png     Germany
# 33   https://cdn.sofifa.com/players/188/545/22_60.png      Poland
#
#                                     Flag  Overall  Potential  \
# 522  https://cdn.sofifa.com/flags/es.png       82         82
# 5    https://cdn.sofifa.com/flags/de.png       89         90
# 1    https://cdn.sofifa.com/flags/de.png       87         88
# 125  https://cdn.sofifa.com/flags/de.png       88         88
# ...

# %%
fc.sort_values(by=['Strength'],ascending=False).head()
# Out:
#            ID            Name  Age  \
# 8698   212190         N. Süle   25
# 1      209658     L. Goretzka   26
# 3667   229558    D. Upamecano   22
# 33     188545  R. Lewandowski   32
# 15492     488      08 O. Kahn   38
#
#                                                   Photo Nationality  \
# 8698   https://cdn.sofifa.com/players/212/190/22_60.png     Germany
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 3667   https://cdn.sofifa.com/players/229/558/22_60.png      France
# 33     https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 15492  https://cdn.sofifa.com/players/000/488/08_60.png     Germany
#
#                                       Flag  Overall  Potential  \
# 8698   https://cdn.sofifa.com/flags/de.png       82         87
# 1      https://cdn.sofifa.com/flags/de.png       87         88
# 3667   https://cdn.sofifa.com/flags/fr.png       82         90
# 33     https://cdn.sofifa.com/flags/pl.png       92         92
# ...

# %%
fc['Nationality'].value_counts()
# Out:
# Germany          14
# France            8
# Spain             3
# Austria           1
# Poland            1
# Canada            1
# Brazil            1
# Cameroon          1
# England           1
# United States     1
# Croatia           1
# Name: Nationality, dtype: int64
